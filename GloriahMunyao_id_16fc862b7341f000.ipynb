# %%
import pandas as pd


file_path = r'C:\Hamoye\energydata_complete.csv'

# Load the dataset into a pandas DataFrame
data = pd.read_csv(file_path)

# Now you can work with the 'data' DataFrame
# For example, you can print the first few rows of the dataset
display(data.head())
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score


temp1 = data[['T2']]
temp2 = data['T6']

# Creating a linear regression model
model = LinearRegression()

# Fitting the model to the data
model.fit(temp1, temp2)

# Predicting the target variable
temp2pred = model.predict(temp1)

# Calculating the R squared value
rSquared = r2_score(temp2, pred)
rSquaredRounded = round(rSquared, 2)

print("R squared:", rSquaredRounded)
# Out:
# R squared: 0.64

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# Loading the dataset
file_path = r'C:\Hamoye\energydata_complete.csv'
data = pd.read_csv(file_path)

# Removing columns "date" and "lights"
removeColumns = ["date", "lights"]
data = data.drop(removeColumns, axis=1)

# Normalize the dataset using MinMaxScaler
scaler = MinMaxScaler()
normalizedData = scaler.fit_transform(data)

# Convert the normalized data back to a DataFrame
normalizedData = pd.DataFrame(normalizedData, columns=data.columns)

#Target variable as "Appliances"
target = normalizedData["Appliances"]

#Features variable to be all columns except "Appliances"
features = normalizedData.drop("Appliances", axis=1)

# Splitting the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=42)

# Fitting a multiple linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Predicting the target variable for the test data
temp2pred = model.predict(X_test)

# Calculate the Mean Absolute Error (MAE)
MAE = mean_absolute_error(y_test, y_pred)
MAErounded = round(MAE, 2)

print("MAE:", MAErounded)
# Out:
# MAE: 0.05

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression

# Loading the dataset
file_path = r'C:\Hamoye\energydata_complete.csv'
data = pd.read_csv(file_path)

# Removing columns "date" and "lights"
removeColumns = ["date", "lights"]
data = data.drop(removeColumns, axis=1)

# Normalize the dataset using MinMaxScaler
scaler = MinMaxScaler()
normalizedData = scaler.fit_transform(data)

# Convert the normalized data back to a DataFrame
normalizedData = pd.DataFrame(normalizedData, columns=data.columns)

#Target variable as "Appliances"
target = normalizedData["Appliances"]

#Features variable to be all columns except "Appliances"
features = normalizedData.drop("Appliances", axis=1)

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=42)

# Fitting a multiple linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Predict the target variable for the test data
temp2pred = model.predict(X_test)

# Calculate the Residual Sum of Squares (RSS)
Res = y_test - temp2pred
RSS = (Res ** 2).sum()
RSSrounded = round(RSS, 2)

print("RSS:", RSSrounded)
# Out:
# RSS: 45.35

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np

# Loading the dataset
file_path = r'C:\Hamoye\energydata_complete.csv'
data = pd.read_csv(file_path)

# Removing columns "date" and "lights"
removeColumns = ["date", "lights"]
data = data.drop(removeColumns, axis=1)

# Normalizing the dataset using MinMaxScaler
scaler = MinMaxScaler()
normalizedData = scaler.fit_transform(data)

# Converting the normalized data back to a DataFrame
normalizedData = pd.DataFrame(normalizedData, columns=data.columns)

#Target variable as "Appliances"
target = normalizedData["Appliances"]

#Features variable to be all columns except "Appliances"
features = normalizedData.drop("Appliances", axis=1)

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=42)

# Fit a multiple linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# PredictING the target variable for the test data
temp2pred = model.predict(X_test)

# Calculating the RMSE
MSE = mean_squared_error(y_test, temp2pred)
RMSE = np.sqrt(MSE)
RMSErounded = round(RMSE, 3)

print("RMSE:", RMSErounded)
# Out:
# RMSE: 0.088

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression

# Loading the dataset
file_path = r'C:\Hamoye\energydata_complete.csv'
data = pd.read_csv(file_path)

# Removing columns "date" and "lights"
removeColumns = ["date", "lights"]
data = data.drop(removeColumns, axis=1)

# Normalizing the dataset using MinMaxScaler
scaler = MinMaxScaler()
normalizedData = scaler.fit_transform(data)

# Converting the normalized data back to a DataFrame
normalizedData = pd.DataFrame(normalizedData, columns=data.columns)

#Target variable as "Appliances"
target = normalizedData["Appliances"]

#Features variable to be all columns except "Appliances"
features = normalizedData.drop("Appliances", axis=1)

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=42)

# Fitting a multiple linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Calculate the coefficient of determination (R squared)
rSquared = model.score(X_test, y_test)
rSquaredRounded = round(rSquared, 2)

print("Coefficient of Determination (R squared):", rSquaredRounded)
# Out:
# Coefficient of Determination (R squared): 0.15

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression

# Loading the dataset
file_path = r'C:\Hamoye\energydata_complete.csv'
data = pd.read_csv(file_path)

# Removing columns "date" and "lights"
removeColumns = ["date", "lights"]
data = data.drop(removeColumns, axis=1)

# Normalizing the dataset using MinMaxScaler
scaler = MinMaxScaler()
normalizedData = scaler.fit_transform(data)

# Converting the normalized data back to a DataFrame
normalizedData = pd.DataFrame(normalizedData, columns=data.columns)

#Target variable as "Appliances"
target = normalizedData["Appliances"]

#Features variable to be all columns except "Appliances"
features = normalizedData.drop("Appliances", axis=1)


# Splitting the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=42)

# Fitting a multiple linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Getting the feature weights
featureWeights = pd.Series(model.coef_, index=features.columns)

# Find the features with the lowest and highest weights
lowest_weightFeature = featureWeights.idxmin()
highest_weightFeature = featureWeights.idxmax()

print("Lowest weight:", lowest_weightFeature)
print("Highest weight:", highest_weightFeature)
# Out:
# Lowest weight: RH_2
# Highest weight: RH_1

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# Loading the dataset
file_path = r'C:\Hamoye\energydata_complete.csv'
data = pd.read_csv(file_path)

# Removing columns "date" and "lights"
removeColumns = ["date", "lights"]
data = data.drop(removeColumns, axis=1)

# Normalizing the dataset using MinMaxScaler
scaler = MinMaxScaler()
normalizedData = scaler.fit_transform(data)

# Converting the normalized data back to a DataFrame
normalizedData = pd.DataFrame(normalizedData, columns=data.columns)

#Target variable as "Appliances"
target = normalizedData["Appliances"]

#Features variable to be all columns except "Appliances"
features = normalizedData.drop("Appliances", axis=1)


# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    features, target, test_size=0.3, random_state=42
)

# Train a Ridge regression model with alpha=0.4
ridgeModel = Ridge(alpha=0.4)
ridgeModel.fit(X_train, y_train)

# Make predictions on the test set using the Ridge model
temp2_ridge = ridgeModel.predict(X_test)

# Calculate the RMSE for the Ridge model
RMSEridge = mean_squared_error(y_test, temp2_ridge, squared=False)

print("RMSE with Ridge Regression:", RMSEridge)
# Out:
# RMSE with Ridge Regression: 0.08753385704628003

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import Lasso

# Load the dataset
file_path = r'C:\Hamoye\energydata_complete.csv'
data = pd.read_csv(file_path)

# Remove columns "date" and "lights"
columns_to_remove = ["date", "lights"]
data = data.drop(columns_to_remove, axis=1)

# Normalize the dataset using MinMaxScaler
scaler = MinMaxScaler()
normalized_data = scaler.fit_transform(data)

# Convert the normalized data back to a DataFrame
normalized_data = pd.DataFrame(normalized_data, columns=data.columns)

# Set the target variable as "Appliances"
target = normalized_data["Appliances"]

# Set the features (all columns except "Appliances")
features = normalized_data.drop("Appliances", axis=1)

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=42)

# Fit a Lasso regression model
lasso_model = Lasso(alpha=0.001)
lasso_model.fit(X_train, y_train)

# Get the feature weights
feature_weights = pd.Series(lasso_model.coef_, index=features.columns)

# Count the number of features with non-zero weights
non_zero_features = sum(feature_weights != 0)

print("Number of features with non-zero feature weights:", non_zero_features)
# Out:
# Number of features with non-zero feature weights: 4

# %%
import numpy as np
from sklearn.metrics import mean_squared_error

# Use the Lasso regression model to make predictions on the test set
lasso_predictions = lasso_model.predict(X_test)

# Calculate the RMSE
lasso_rmse = np.sqrt(mean_squared_error(y_test, lasso_predictions))

# Print the RMSE with three decimal places
print("RMSE with Lasso regression:", '{:.3f}'.format(lasso_rmse))
# Out:
# RMSE with Lasso regression: 0.094
